# %% [markdown]
# #                     Regression (linear and nonlinear with multiple variable)

# %% [markdown]
# ### Importing the dataset

# %%
import pandas as pd
data_set = pd.read_csv("C:/Users/DELL/Desktop/HITK ML NOTEBOOKS/MV_Reg_noisy_data.csv")

# %%
data_set
# Out:
#             x         y
# 0    3.068406 -3.755872
# 1    1.923489 -4.195847
# 2    1.888703 -0.728367
# 3    3.663629  0.933993
# 4    2.265348 -5.185469
# ..        ...       ...
# 295  2.704274 -0.890898
# 296  2.311912 -2.040911
# 297  0.956126 -4.873227
# 298  4.210267 -1.093269
# 299  2.747562  0.877354
#
# [300 rows x 2 columns]

# %% [markdown]
# ### Plotting all the points in the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
x = []
y = []

file_name = "C:/Users/DELL/Desktop/HITK ML NOTEBOOKS/MV_Reg_noisy_data.csv"
with open(file_name, mode = 'r') as file:
    csvFile = csv.reader(file)
    flag = 0
    for row in csvFile:
        if flag == 0:
            flag = 1
            continue
        else:
            x.append(float(row[0]))
            y.append(float(row[1]))

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Where α is the learning parameter.

# %% [markdown]
# # PART 1: Observing how the Squared Sum Error decreases with each iteration for different hypotheses used   [training data = 70%, test data = 30%]

# %% [markdown]
# ## ***SIMPLE LINEAR REGRESSION

# %% [markdown]
# ### Hypothesis function                                 y = w0 + w1*x

# %%
alpha = 0.001          # Learning rate 

def lin_regression(num_of_iterations, num_of_training_samples):
    in_sample_error = []
    out_sample_error = []
    iteration = []
    i = 1
    w = [2, 2]         # Initial assumption
    while (i <= num_of_iterations):
        j = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            w[0] -= alpha * ( w[0] + w[1]*X - Y)
            w[1] -= alpha * ( w[0] + w[1]*X - Y)*X
            j += 1
        
        j = 0
        in_error = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            in_error += ((Y - w[0] - w[1]*X)**2)
            j += 1
        in_error = in_error / (2 * num_of_training_samples) 
        
        j = num_of_training_samples
        out_error = 0
        while j < 300:
            X = x[j]
            Y = y[j]
            out_error += ((Y - w[0] - w[1]*X)**2)
            j += 1
        out_error = out_error / (2 * (300 - num_of_training_samples))
        
        in_sample_error.append(in_error)
        out_sample_error.append(out_error)
        iteration.append(i)
        i +=1
    return w, iteration, in_sample_error, out_sample_error

# %% [markdown]
# ### Plotting the gradual decrease of SSE

# %%
coefficients, iteration, in_sample_error, out_sample_error = lin_regression(100, 210)
f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(iteration, in_sample_error, label = "in_sample error")
plt.plot(iteration, out_sample_error, label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with each iteration....")
plt.xlabel("Iteration count --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ###  Plotting the best fit curve  [y = w0 + w1*x]

# %%
line_x = [0, 5]
line_y = [coefficients[0], 5*coefficients[1] + coefficients[0]]
plt.plot(line_x, line_y, color = 'red')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ##  ***MULTIVARIATE REGRESSION [ degree = 2 (QUADRATIC) ]

# %% [markdown]
# ### Hypothesis function y = w0 + w1*x + w2*x^2

# %%
alpha = 0.001          # Learning rate 

def quad_regression(num_of_iterations, num_of_training_samples):
    in_sample_error = []
    out_sample_error = []
    iteration = []
    i = 1
    w = [2, 2, 2]      # Initial assumption
    while (i <= num_of_iterations):
        j = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            w[0] -= alpha * ( w[0] + w[1]*X + w[2]*X*X - Y)
            w[1] -= alpha * ( w[0] + w[1]*X + w[2]*X*X - Y)*X
            w[2] -= alpha * ( w[0] + w[1]*X + w[2]*X*X - Y)*X**2
            j += 1
        
        j = 0
        in_error = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            in_error += ((Y - w[0] - w[1]*X - w[2]*X*X)**2)
            j += 1
        in_error = in_error / (2 * num_of_training_samples) 
        
        j = num_of_training_samples
        out_error = 0
        while j < 300:
            X = x[j]
            Y = y[j]
            out_error += ((Y - w[0] - w[1]*X - w[2]*X*X)**2)
            j += 1
        out_error = out_error / (2 * (300 - num_of_training_samples))
        
        in_sample_error.append(in_error)
        out_sample_error.append(out_error)
        iteration.append(i)
        i +=1
    return w, iteration, in_sample_error, out_sample_error

# %% [markdown]
# ### Plotting the gradual decrease of SSE

# %%
coefficients, iteration, in_sample_error, out_sample_error = quad_regression(100, 210)
f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(iteration, in_sample_error, label = "in_sample error")
plt.plot(iteration, out_sample_error, label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with each iteration....")
plt.xlabel("Iteration count --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting the best fit curve [y = w0 + w1*x + w2x^2]

# %%
line_x = np.linspace(-1,6,5000)
line_y = coefficients[0] + coefficients[1]*line_x + coefficients[2]*line_x**2
plt.plot(line_x, line_y, color = 'red')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## ***MULTIVARIATE REGRESSION [ degree = 3 (CUBIC) ]

# %% [markdown]
# ### Hypothesis function y = w0 + w1*x + w2*x^2 + w3*x^3

# %%
alpha = 0.0001          # Learning rate 

def cubic_regression(num_of_iterations, num_of_training_samples):
    in_sample_error = []
    out_sample_error = []
    iteration = []
    i = 1
    w = [2, 2, 2, 2]      # Initial assumption
    while (i <= num_of_iterations):
        j = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            w[0] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X - Y)
            w[1] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X - Y)*X
            w[2] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X - Y)*X**2
            w[3] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X - Y)*X**3
            j += 1
        
        j = 0
        in_error = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            in_error += (Y - w[0] - w[1]*X - w[2]*X*X - w[3]*X*X*X)**2
            j += 1
        in_error = in_error / (2 * num_of_training_samples) 
        
        j = num_of_training_samples
        out_error = 0
        while j < 300:
            X = x[j]
            Y = y[j]
            out_error += ((Y - w[0] - w[1]*X - w[2]*X*X - w[3]*X*X*X)**2)
            j += 1
        out_error = out_error / (2 * (300 - num_of_training_samples))
        
        in_sample_error.append(in_error)
        out_sample_error.append(out_error)
        iteration.append(i)
        i +=1
    return w, iteration, in_sample_error, out_sample_error

# %% [markdown]
# ### Plotting the gradual decrease of SSE

# %%
coefficients, iteration, in_sample_error, out_sample_error = cubic_regression(100, 210)
f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(iteration, in_sample_error, label = "in_sample error")
plt.plot(iteration, out_sample_error, label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with each iteration....")
plt.xlabel("Iteration count --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting the best fit curve [ y = w0 + w1x + w2x^2 + w3*x^3 ]

# %%
line_x = np.linspace(-1,6,5000)
line_y = coefficients[0] + coefficients[1]*line_x + coefficients[2]*line_x**2 + coefficients[3]*line_x**3
plt.plot(line_x, line_y, color = 'red')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## ***MULTIVARIATE REGRESSION [ degree = 4 ]

# %% [markdown]
# ### Hypothesis function y = w0 + w1x + w2x^2 + w3*x^3 + w4*x^4

# %%
alpha = 0.0001          # Learning rate 

def deg4_regression(num_of_iterations, num_of_training_samples):
    in_sample_error = []
    out_sample_error = []
    iteration = []
    i = 1
    w = [2, 2, 2, 2, 2]      # Initial assumption
    while (i <= num_of_iterations):
        j = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            w[0] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X + w[4]*X*X*X*X - Y)
            w[1] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X + w[4]*X*X*X*X - Y)*X
            w[2] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X + w[4]*X*X*X*X - Y)*X**2
            w[3] -= alpha * ( w[0] + w[1]*X + w[2]*X*X + w[3]*X*X*X + w[4]*X*X*X*X - Y)*X**3
            j += 1
        
        j = 0
        in_error = 0
        while j < num_of_training_samples:
            X = x[j]
            Y = y[j]
            in_error += (Y - w[0] - w[1]*X - w[2]*X*X - w[3]*X*X*X - w[4]*X*X*X*X)**2
            j += 1
        in_error = in_error / (2 * num_of_training_samples) 
        
        j = num_of_training_samples
        out_error = 0
        while j < 300:
            X = x[j]
            Y = y[j]
            out_error += ((Y - w[0] - w[1]*X - w[2]*X*X - w[3]*X*X*X - w[4]*X*X*X*X)**2)
            j += 1
        out_error = out_error / (2 * (300 - num_of_training_samples))
        
        in_sample_error.append(in_error)
        out_sample_error.append(out_error)
        iteration.append(i)
        i +=1
    return w, iteration, in_sample_error, out_sample_error

# %% [markdown]
# ### Plotting the gradual decrease of SSE

# %%
coefficients, iteration, in_sample_error, out_sample_error = deg4_regression(100, 210)
f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(iteration, in_sample_error, label = "in_sample error")
plt.plot(iteration, out_sample_error, label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with each iteration....")
plt.xlabel("Iteration count --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting the best fit curve [ y = w0 + w1x + w2x^2 + w3x^3 + w4x^4 ]

# %%
l_x = np.linspace(0,5,5000)
line_y = coefficients[0] + coefficients[1]*l_x + coefficients[2]*l_x**2 + coefficients[3]*l_x**3 + coefficients[4]*l_x**4
plt.plot(l_x, line_y, color = 'red')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # PART 2: Observing how the results change with the increase in the number training samples for different hypotheses used

# %% [markdown]
# ## SIMPLE LINEAR REGRESSION

# %%
coefficients, iteration, in_sample_error, out_sample_error = lin_regression(100, 5)
in_avg5 = sum(in_sample_error) / len(in_sample_error)
out_avg5 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = lin_regression(100, 10)
in_avg10 = sum(in_sample_error) / len(in_sample_error)
out_avg10 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = lin_regression(100, 20)
in_avg20 = sum(in_sample_error) / len(in_sample_error)
out_avg20 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = lin_regression(100, 50)
in_avg50 = sum(in_sample_error) / len(in_sample_error)
out_avg50 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = lin_regression(100, 100)
in_avg100 = sum(in_sample_error) / len(in_sample_error)
out_avg100 = sum(out_sample_error) / len(out_sample_error)

in_y = [in_avg5, in_avg10, in_avg20, in_avg50, in_avg100]
out_y = [out_avg5, out_avg10, out_avg20, out_avg50, out_avg100]
range_x = [5, 10, 20, 50, 100]

f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(range_x, in_y, color ='maroon', label = "in_sample error")
plt.plot(range_x, out_y, color ='blue', label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with increase in training set size (LINEAR REGRESSION) ....")
plt.xlabel("Training set size --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ## MULTIVARIATE REGRESSION [ degree = 2 (QUADRATIC) ]

# %%
coefficients, iteration, in_sample_error, out_sample_error = quad_regression(100, 5)
in_avg5 = sum(in_sample_error) / len(in_sample_error)
out_avg5 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = quad_regression(100, 10)
in_avg10 = sum(in_sample_error) / len(in_sample_error)
out_avg10 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = quad_regression(100, 20)
in_avg20 = sum(in_sample_error) / len(in_sample_error)
out_avg20 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = quad_regression(100, 50)
in_avg50 = sum(in_sample_error) / len(in_sample_error)
out_avg50 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = quad_regression(100, 100)
in_avg100 = sum(in_sample_error) / len(in_sample_error)
out_avg100 = sum(out_sample_error) / len(out_sample_error)

in_y = [in_avg5, in_avg10, in_avg20, in_avg50, in_avg100]
out_y = [out_avg5, out_avg10, out_avg20, out_avg50, out_avg100]
range_x = [5, 10, 20, 50, 100]

f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(range_x, in_y, color ='maroon', label = "in_sample error")
plt.plot(range_x, out_y, color ='blue', label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with increase in training set size (QUADRATIC REGRESSION)....")
plt.xlabel("Training set size --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ## MULTIVARIATE REGRESSION [ degree = 3 (CUBIC) ]

# %%
coefficients, iteration, in_sample_error, out_sample_error = cubic_regression(100, 5)
in_avg5 = sum(in_sample_error) / len(in_sample_error)
out_avg5 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = cubic_regression(100, 10)
in_avg10 = sum(in_sample_error) / len(in_sample_error)
out_avg10 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = cubic_regression(100, 20)
in_avg20 = sum(in_sample_error) / len(in_sample_error)
out_avg20 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = cubic_regression(100, 50)
in_avg50 = sum(in_sample_error) / len(in_sample_error)
out_avg50 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = cubic_regression(100, 100)
in_avg100 = sum(in_sample_error) / len(in_sample_error)
out_avg100 = sum(out_sample_error) / len(out_sample_error)

in_y = [in_avg5, in_avg10, in_avg20, in_avg50, in_avg100]
out_y = [out_avg5, out_avg10, out_avg20, out_avg50, out_avg100]
range_x = [5, 10, 20, 50, 100]

f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(range_x, in_y, color ='maroon', label = "in_sample error")
plt.plot(range_x, out_y, color ='blue', label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with increase in training set size (CUBIC REGRESSION)....")
plt.xlabel("Training set size --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()

# %% [markdown]
# ## MULTIVARIATE REGRESSION [ degree = 4 ]

# %%
coefficients, iteration, in_sample_error, out_sample_error = deg4_regression(100, 5)
in_avg5 = sum(in_sample_error) / len(in_sample_error)
out_avg5 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = deg4_regression(100, 10)
in_avg10 = sum(in_sample_error) / len(in_sample_error)
out_avg10 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = deg4_regression(100, 20)
in_avg20 = sum(in_sample_error) / len(in_sample_error)
out_avg20 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = deg4_regression(100, 50)
in_avg50 = sum(in_sample_error) / len(in_sample_error)
out_avg50 = sum(out_sample_error) / len(out_sample_error)

coefficients, iteration, in_sample_error, out_sample_error = deg4_regression(100, 100)
in_avg100 = sum(in_sample_error) / len(in_sample_error)
out_avg100 = sum(out_sample_error) / len(out_sample_error)

in_y = [in_avg5, in_avg10, in_avg20, in_avg50, in_avg100]
out_y = [out_avg5, out_avg10, out_avg20, out_avg50, out_avg100]
range_x = [5, 10, 20, 50, 100]

f = plt.figure()
f.set_figwidth(10)    
f.set_figheight(5)
plt.plot(range_x, in_y, color ='maroon', label = "in_sample error")
plt.plot(range_x, out_y, color ='blue', label = "out_sample error")
plt.title("How Sum of Square Error(S.S.E.) decreases with increase in training set size (POLYNOMIAL REGRESSION of degree 4)....")
plt.xlabel("Training set size --->")
plt.ylabel("S.S.E. --->")
plt.legend()
plt.show()
